# %%
import pandas as pd

raw = pd.read_json("https://raw.githubusercontent.com/Biuni/PokemonGO-Pokedex/master/pokedex.json")
df = pd.json_normalize(raw["pokemon"])

#handling all the null values
df['candy_count'] = df['candy_count'].fillna(0)

df['multipliers'] = df['multipliers'].fillna('[0]')

df['next_evolution'] = df['next_evolution'].fillna("[{'num': 'unknown', 'name': 'unknown'}]")

df['prev_evolution'] = df['prev_evolution'].fillna("[{'num': 'unknown', 'name': 'unknown'}]")

#changing columns data type according the ask
columns_to_int = ['num', 'candy_count']
df[columns_to_int] = df[columns_to_int].astype('int') # changing data type to int


df = df.rename(columns={'spawn_time':'minutes: seconds'})# renaming the spawn_time column as asked

df['height'] = df['height'].str.replace(' m', '')# stripping m
df['weight'] = df['weight'].str.replace(' kg', '')# stripping kg
columns_to_float = ['height','weight']
df[columns_to_float]= df[columns_to_float].astype('float')# changing data type to float

df['egg']= df['egg'].replace(to_replace='Not in Eggs',value = '0') #handling the values
df['egg'] = df['egg'].str.replace(' km', '') #stripping km
df['egg'] = df['egg'].str.replace('Omanyte Candy', '0') #changing 'Omanyte Candy' to 0 so it won't throw error while changing data type
df['egg']= df['egg'].astype('float')# changing data type to float

df['spawn_chance'] = df['spawn_chance'] * 100 #converting spawn chance values to percentage

df['avg_spawns'] = df['avg_spawns'] / 10.000 #average spawns in 10.000 times
df['avg_spawns'] = df['avg_spawns'].astype('int')#coverting data type to int

df.to_excel('output.xlsx', index=False)# returning it in excel format

# %%
df.head(10)
# Out:
#    id  num        name                                               img  \
# 0   1    1   Bulbasaur  http://www.serebii.net/pokemongo/pokemon/001.png
# 1   2    2     Ivysaur  http://www.serebii.net/pokemongo/pokemon/002.png
# 2   3    3    Venusaur  http://www.serebii.net/pokemongo/pokemon/003.png
# 3   4    4  Charmander  http://www.serebii.net/pokemongo/pokemon/004.png
# 4   5    5  Charmeleon  http://www.serebii.net/pokemongo/pokemon/005.png
# 5   6    6   Charizard  http://www.serebii.net/pokemongo/pokemon/006.png
# 6   7    7    Squirtle  http://www.serebii.net/pokemongo/pokemon/007.png
# 7   8    8   Wartortle  http://www.serebii.net/pokemongo/pokemon/008.png
# 8   9    9   Blastoise  http://www.serebii.net/pokemongo/pokemon/009.png
# 9  10   10    Caterpie  http://www.serebii.net/pokemongo/pokemon/010.png
#
#               type  height  weight             candy  candy_count  egg  \
# 0  [Grass, Poison]    0.71     6.9   Bulbasaur Candy           25  2.0
# 1  [Grass, Poison]    0.99    13.0   Bulbasaur Candy          100  0.0
# 2  [Grass, Poison]    2.01   100.0   Bulbasaur Candy            0  0.0
# 3           [Fire]    0.61     8.5  Charmander Candy           25  2.0
# 4           [Fire]    1.09    19.0  Charmander Candy          100  0.0
# 5   [Fire, Flying]    1.70    90.5  Charmander Candy            0  0.0
# 6          [Water]    0.51     9.0    Squirtle Candy           25  2.0
# 7          [Water]    0.99    22.5    Squirtle Candy          100  0.0
# 8          [Water]    1.60    85.5    Squirtle Candy            0  0.0
# 9            [Bug]    0.30     2.9    Caterpie Candy           12  2.0
#
#    spawn_chance  avg_spawns minutes: seconds multipliers  \
# 0         69.00           6            20:00      [1.58]
# 1          4.20           0            07:00  [1.2, 1.6]
# 2          1.70           0            11:30         [0]
# 3         25.30           2            08:45      [1.65]
# 4          1.20           0            19:00      [1.79]
# 5          0.31           0            13:34         [0]
# 6         58.00           5            04:25       [2.1]
# 7          3.40           0            07:02       [1.4]
# 8          0.67           0            00:06         [0]
# 9        303.20          30            16:35      [1.05]
#
#                      weaknesses  \
# 0  [Fire, Ice, Flying, Psychic]
# 1  [Fire, Ice, Flying, Psychic]
# 2  [Fire, Ice, Flying, Psychic]
# 3         [Water, Ground, Rock]
# 4         [Water, Ground, Rock]
# 5       [Water, Electric, Rock]
# 6             [Electric, Grass]
# 7             [Electric, Grass]
# 8             [Electric, Grass]
# 9          [Fire, Flying, Rock]
#
#                                       next_evolution  \
# 0  [{'num': '002', 'name': 'Ivysaur'}, {'num': '0...
# 1               [{'num': '003', 'name': 'Venusaur'}]
# 2                                            [{0:0}]
# 3  [{'num': '005', 'name': 'Charmeleon'}, {'num':...
# 4              [{'num': '006', 'name': 'Charizard'}]
# 5                                            [{0:0}]
# 6  [{'num': '008', 'name': 'Wartortle'}, {'num': ...
# 7              [{'num': '009', 'name': 'Blastoise'}]
# 8                                            [{0:0}]
# 9  [{'num': '011', 'name': 'Metapod'}, {'num': '0...
#
#                                       prev_evolution
# 0            [{'num': 'unknown', 'name': 'unknown'}]
# 1              [{'num': '001', 'name': 'Bulbasaur'}]
# 2  [{'num': '001', 'name': 'Bulbasaur'}, {'num': ...
# 3            [{'num': 'unknown', 'name': 'unknown'}]
# 4             [{'num': '004', 'name': 'Charmander'}]
# 5  [{'num': '004', 'name': 'Charmander'}, {'num':...
# 6            [{'num': 'unknown', 'name': 'unknown'}]
# 7               [{'num': '007', 'name': 'Squirtle'}]
# 8  [{'num': '007', 'name': 'Squirtle'}, {'num': '...
# 9            [{'num': 'unknown', 'name': 'unknown'}]

# %%
# Out:
#    id  num        name                                               img  \
# 0   1    1   Bulbasaur  http://www.serebii.net/pokemongo/pokemon/001.png
# 1   2    2     Ivysaur  http://www.serebii.net/pokemongo/pokemon/002.png
# 2   3    3    Venusaur  http://www.serebii.net/pokemongo/pokemon/003.png
# 3   4    4  Charmander  http://www.serebii.net/pokemongo/pokemon/004.png
# 4   5    5  Charmeleon  http://www.serebii.net/pokemongo/pokemon/005.png
#
#               type  height  weight             candy  candy_count  egg  \
# 0  [Grass, Poison]    0.71     6.9   Bulbasaur Candy           25  2.0
# 1  [Grass, Poison]    0.99    13.0   Bulbasaur Candy          100  0.0
# 2  [Grass, Poison]    2.01   100.0   Bulbasaur Candy            0  0.0
# 3           [Fire]    0.61     8.5  Charmander Candy           25  2.0
# 4           [Fire]    1.09    19.0  Charmander Candy          100  0.0
#
#    spawn_chance  avg_spawns minutes: seconds multipliers  \
# 0          69.0           6            20:00      [1.58]
# 1           4.2           0            07:00  [1.2, 1.6]
# 2           1.7           0            11:30         [0]
# 3          25.3           2            08:45      [1.65]
# 4           1.2           0            19:00      [1.79]
#
#                      weaknesses  \
# 0  [Fire, Ice, Flying, Psychic]
# 1  [Fire, Ice, Flying, Psychic]
# 2  [Fire, Ice, Flying, Psychic]
# 3         [Water, Ground, Rock]
# 4         [Water, Ground, Rock]
#
#                                       next_evolution  \
# 0  [{'num': '002', 'name': 'Ivysaur'}, {'num': '0...
# 1               [{'num': '003', 'name': 'Venusaur'}]
# 2                                            [{0:0}]
# 3  [{'num': '005', 'name': 'Charmeleon'}, {'num':...
# 4              [{'num': '006', 'name': 'Charizard'}]
#
#                                       prev_evolution
# 0            [{'num': 'unknown', 'name': 'unknown'}]
# 1              [{'num': '001', 'name': 'Bulbasaur'}]
# 2  [{'num': '001', 'name': 'Bulbasaur'}, {'num': ...
# 3            [{'num': 'unknown', 'name': 'unknown'}]
# 4             [{'num': '004', 'name': 'Charmander'}]
